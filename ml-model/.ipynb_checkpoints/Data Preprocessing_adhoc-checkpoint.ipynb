# %% [markdown]
# # Vk data preprocessing for further modelling

# %%
import pandas as pd
import numpy as np

import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from pymystem3 import Mystem
from tqdm import tqdm_notebook

from string import punctuation

import sys
sys.path.append('../')
from src.utils import remove_name_from_text
from src.log_progress import log_progress

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
raw_data =  pd.read_csv('vk_posts_adhoc.csv').loc[:, ['id', 'date', 'owner_id', 'text', 'likes', 'reposts', 'comments']]
raw_data.head()
# Out:
#       id        date  owner_id  \
# 0   4259  1547411913 -20762107
# 1   9896  1547405952 -45668536
# 2  17976  1547396554 -64025511
# 3  17974  1547396064 -64025511
# 4   5593  1547394772  -8775943
#
#                                                 text  likes  reposts  comments
# 0  Высшая лига А. 9 тур. 2 день / Результаты 📋\n\...     12        0         0
# 1  12-13 января в рамках 9-го тура Чемпионата Рос...     17        0         0
# 2                                                NaN     17        3         0
# 3  Наставник «Тюмени-ТюмГУ» Наталья Васильченко -...     13        3         0
# 4  Яна Чередникова: «За первую партию нас ругают»...      6        2         0

# %%
print('Количество постов:', len(raw_data))
# Out:
# Количество постов: 24622

# %%
#vk_posts['date'] = pd.to_datetime(vk_posts['date'], unit='s')
#vk_posts = vk_posts.sort_values(by='date')
print('Количество дублирующихся постов:', raw_data.duplicated(subset='text').sum())
# Out:
# Количество дублирующихся постов: 3051

# %%
data = raw_data.drop_duplicates(subset='text').reset_index(drop=True)
print('Постов после удаления дубликатов:', len(data))
# Out:
# Постов после удаления дубликатов: 21571

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21571 entries, 0 to 21570
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        21571 non-null  int64
#  1   date      21571 non-null  int64
#  2   owner_id  21571 non-null  int64
#  3   text      21570 non-null  object
#  4   likes     21571 non-null  int64
#  5   reposts   21571 non-null  int64
#  6   comments  21571 non-null  int64
# dtypes: int64(6), object(1)
# memory usage: 1.1+ MB

# %%
data['date'] = pd.to_datetime(data['date'], unit='s')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21571 entries, 0 to 21570
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        21571 non-null  int64
#  1   date      21571 non-null  datetime64[ns]
#  2   owner_id  21571 non-null  int64
#  3   text      21570 non-null  object
#  4   likes     21571 non-null  int64
#  5   reposts   21571 non-null  int64
#  6   comments  21571 non-null  int64
# dtypes: datetime64[ns](1), int64(5), object(1)
# memory usage: 1.1+ MB

# %%
data = data.dropna().reset_index(drop=True)
print('После удаления пустых значений осталось', len(data), 'записей')
# Out:
# После удаления пустых значений осталось 21570 записей

# %%
print('Количество дублирующихся строк:', data.duplicated().sum())
# Out:
# Количество дублирующихся строк: 0

# %%
data['txt_processed'] = data['text'].apply(lambda x: re.sub(r'[^\w\s]', ' ', x.lower()))
data['txt_processed'] = data['txt_processed'].apply(lambda x: re.sub(r'\n+', ' ', x))
data['txt_processed'] = data['txt_processed'].apply(lambda x: re.sub(r'\d+', '', x))
data['txt_processed'] = data['txt_processed'].apply(lambda x: re.sub(r'id\w+', '', x))
data['txt_processed'] = data['txt_processed'].apply(lambda x: re.sub(r'[A-Za-z]+', '', x))

data['txt_processed'] = data['txt_processed'].apply(lambda x: re.sub(r'\s+', ' ', x))
data['txt_processed'] = data['txt_processed'].apply(lambda x: x.strip())
data['txt_processed'].tail()
# Out:
# 21565    новый год любимый с детства праздник самый кра...
# 21566    _ год стал годом инноваций стимулом поиска нов...
# 21567    ассорти достижений декабрь часть приближается ...
# 21568    топ разработок сибирских ученых в году на порт...
# 21569    поиск волонтёров с января по февраля в тюмгу п...
# Name: txt_processed, dtype: object

# %%
lem = Mystem()
nltk.download('stopwords')
stop = stopwords.words('russian')

def preprocess_text(x):
    word_list = []
    for word in (''.join(lem.lemmatize(x))).split(' '):
        if word not in stop and word != '':
            word_list.append(word.rstrip())
    return word_list
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Зима\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop.extend([
u'я', u'а', u'да', u'но', u'тебе', u'мне', u'ты', u'и', u'у', u'на', u'ща', u'ага',
u'так', u'там', u'какие', u'который', u'какая', u'туда', u'давай', u'короче', u'кажется', u'вообще',
u'ну', u'не', u'чет', u'неа', u'свои', u'наше', u'наш', u'весь', u'хотя', u'такое', u'например', u'кароч', u'как-то',
u'нам', u'хм', u'всем', u'нет', u'да', u'оно', u'своем', u'про', u'вы', u'м', u'тд',
u'вся', u'кто-то', u'что-то', u'вам', u'это', u'эта', u'эти', u'этот', u'прям', u'либо', u'как', u'мы',
u'просто', u'блин', u'очень', u'самые', u'твоем', u'ваша', u'кстати', u'вроде', u'типа', u'пока', u'ок',
u'мочь'
])

# %%
text_data = data['txt_processed'].to_numpy()

text_data
# Out:
# array(['высшая лига а тур день результаты тюмень тюмгу тюмень приморочка владивосток самрау угнту уфа юзгу атом курская область спарта нижний новгород динамо казань уор казань луч москва северянка череповец тулица тула липецк липецкая обл олимп куйбышев импульс волгодонск свободный от игр тур расположение команд северянка спарта тулица самрау приморочка тюмень тюмгу юзгу атом динамо уор липецк олимп импульс луч вкспарта волейбол высшаялигаа',
#        'января в рамках го тура чемпионата россии среди женских команд высшей лиги а в нижнем новгороде юные казаночки из динамо уор школа гамовой встречались с местной командой спарта й год юные казаночки из динамо уор удачно завершили двумя победами над волгодонским импульсом затем хорошо потренировались во время заметно более длинного праздничного перерыва в высшей лиге а однако вторая половина сезона обещает немало трудностей для подопечных светланы сафроновой во первых все оставшиеся туры будут выездными а во вторых предстоят встречи сплошь с лидерами дивизиона последовательно со спартой тулицей и уфимским самрау угнту в первом матче го тура казанская молодёжная команда навязала борьбу одному из лидеров высшей лиги а нижегородской спарте но в итоге всё же уступила в четырёх сетах высшая лига а й тур й матч спарта динамо уор января нижний новгород дс северная звезда судья болбасова т москва время матча динамо ишимбаева матвеева гошева к акимова горбунова слаутина стартовая шестерка перова либеро мурушкина попова черницова результаты других матчей дня в высшей лиге а самрау угнту юзгу атом тюмень тюмгу приморочка луч северянка тулица липецк во втором матче го тура чемпионата россии среди женских команд высшей лиги а в нижнем новгороде юные казаночки из динамо уор школа гамовой зарубились со спартой на все пять сетов и лишь чуть чуть удачи им не хватило для победы высшая лига а й тур й матч спарта динамо уор января нижний новгород дс северная звезда судья киселёва е санкт петербург результаты других матчей дня в высшей лиге а самрау угнту юзгу атом тюмень тюмгу приморочка луч северянка тулица липецк',
#        'наставник тюмени тюмгу наталья васильченко о втором поражении от приморочки',
#        ...,
#        'ассорти достижений декабрь часть приближается конец года а значит пора подводить итоги сегодня радуемся успехам егора кузнецова анастасии шараповой надежды есаковой сергея сергеевича войтенкова добавляйте в комментариях свои сертификаты и дипломы пишите о радостных событиях своих победах мы рады успеху каждого егор кузнецов делится своими впечатлениями от пройденного обучения обучение было сложное местами непонятное но благодаря спикерам было легко выполнить итоговый тест я очень рад что мне выпала возможность пройти обучение анастасия шарапова завершила обучение по программе инклюзивное волонтерство в университете и рассказывает о том как все прошло обучение было интересным мы познакомились с идеей и философией инклюзии узнали про правильное обращение к людям с инвалидностью поучаствовали в инклюзивном диктанте и др в процессе обучения проходили разнообразные вебинары в т ч мы поучаствовали в одном из мероприятий которое проходило в рамках фестиваля инклюзивной культуры тюмгу инклюзия сила в разнообразии в общем курс был полезен и интересен я получила новые знания и навыки сертификат будет позднее надежда есакова рассказывает о прошедшем обучении подготовка мероприятия на высоком уровне несмотря на дистанционный формат вовлеченность была максимальной интересные практики и домашние задания сегодня мы еще поделимся успехами наших участников проекта в публикациях следите за новостями а в январе года новости про достижения мы традиционно уже опубликуем ближе к концу месяца присылайте заранее свои сертификаты и все чем готовы поделиться на официальную почту молодежного клуба наставников с пометкой в теме письма ассорти достижений январь наставникипроектов ассортидостижений академиянаставников молодежныйклубнаставников итоги',
#        'топ разработок сибирских ученых в году на портале новости сибирской науки можно познакомиться с инновациями и последними достижениями сибирских ученых сегодня мы предлагаем вашему вниманию топ сообщений о наиболее значимых и интересных научных разработках года размещенных на нашем сайте новосибирские учёные создают модель принтера для печати биокерамических имплантов главный специалист технолог института автоматики и электрометрии со ран сергей баев подчёркивает главное достоинство этого метода возможность быстро изготавливать индивидуальную модель время изготовления одного импланта несколько часов это в разы быстрее существующих на рынке технологий старший научный сотрудник института химии твёрдого тела и механохимии со ран наталья булина отмечает что достижением коллектива является ещё и то что смогли сделать диаметр пучка лазера очень маленький всего две десятых миллиметра в результате как ручкой можно рисовать тонкую структуру костной ткани топливо которое растет под ногами с помощью нового катализатора можно получать экологически чистые компоненты моторных топлив патентообладатель институт катализа им г к борескова сибирского отделения российской академии наук сибирские ученые создают высокоточную систему ориентации бпла с возможностью разновысотных измерений создание новой системы ориентации бпла осуществляется специалистами научно исследовательского института радиотехнических систем тусура в рамках российского проекта аэротомография который реализуется на базе новосибирского госуниверситета совместно с институтом нефтегазовой геологии и геофизики им а а трофимука со ран сибирские ученые разработали маски против вирусов исследователи из института химии твердого тела и механохимии со ран разработали материал для медицинских масок имеющий высокую антибактериальную и противовирусную активность она была показана в гнц вб вектор материал разработанный в ихттм со ран состоит из мельтблауна и наносеребра в новосибирске разработали уникальное приложение на основе принципов работы искусственного интеллекта сотрудники научно образовательного центра машинное обучение и анализ больших данных новосибирского государственного университета совместно с институтом катализа им г к борескова со ран занимаются изучением и развитием технологий связанных с глубоким машинным обучением одной из разработок стало приложение которое в режиме может сканировать и анализировать определенные виды микроскопических изображений сибирские ученые создали алгоритм для перевода старой орфографии в современную сотрудники института вычислительных технологий со ран разработали систему которая позволяет переводить дореволюционные издания в современную русскую орфографию практически без участия человека алгоритм может выполнять рутинную работу редакторов и дает исследователям дополнительные инструменты для анализа текстов нагретая растительная биомасса может использоваться в медицине и энергетике российские ученые из института химии твердого тела и механохимии со ран изучили изменения структуры клеточных стенок растений после механической обработки при разной температуре работа опубликована в журнале исследование поддержано президентской программой исследовательских проектов российского научного фонда новосибирские ученые помогут прочитать нарушенную днк исследователи института химической биологии и фундаментальной медицины со ран и новосибирского государственного университета работают над коктейлем из белков который способен помочь в расшифровке деградировавшей днк это важно в частности для палеогенетиков и судмедэкспертов препарат на основе белка плазмы крови сделал мрт безопаснее и точнее сибирские химики разработали органический препарат применяемый врачами перед сеансом магнитно резонансной томографии с использованием контрастных веществ руководитель проекта по гранту рнф главный научный сотрудник новосибирского института органической химии имени н н ворожцова со ран д х н игорь григорьев химики давно заметили потенциал органических препаратов для про ...
#        'поиск волонтёров с января по февраля в тюмгу пройдет региональный этап всероссийской олимпиады школьников без помощи волонтеров не обойтись функционал регистрация служба этикета наблюдение все волонтеры получат благодарственные письма запись в волонтерскую книжку хочешь помочь заполняй форму программа даты проведения и адреса площадок можно найти в прикреплённых файлах стать волонтером можно в любой из дней проведения примерное время работы зависит от выбранного функционала или часов по вопросам обращаться к ирине никулиной'],
#       dtype=object)

# %%
text_data_lemmatized = []
for text in log_progress(text_data, every=1):
    text_data_lemmatized.append(preprocess_text(text))
# Out:
# VBox(children=(HTML(value=''), IntProgress(value=0, max=21570)))

# %%
text_data_lemmatized[0][:10]
# Out:
# ['высокий',
#  'лига',
#  'тур',
#  'день',
#  'результат',
#  'тюмень',
#  'тюмга',
#  'тюмень',
#  'приморочка',
#  'владивосток']

# %%
data['lines_lemmatized'] = text_data_lemmatized
data.head()
# Out:
#       id                date  owner_id  \
# 0   4259 2019-01-13 20:38:33 -20762107
# 1   9896 2019-01-13 18:59:12 -45668536
# 2  17974 2019-01-13 16:14:24 -64025511
# 3   5593 2019-01-13 15:52:52  -8775943
# 4   5591 2019-01-13 15:00:24  -8775943
#
#                                                 text  likes  reposts  \
# 0  Высшая лига А. 9 тур. 2 день / Результаты 📋\n\...     12        0
# 1  12-13 января в рамках 9-го тура Чемпионата Рос...     17        0
# 2  Наставник «Тюмени-ТюмГУ» Наталья Васильченко -...     13        3
# 3  Яна Чередникова: «За первую партию нас ругают»...      6        2
# 4  Наталья Васильченко: «Девчонки плакали, я еле ...     17        2
#
#    comments                                      txt_processed  \
# 0         0  высшая лига а тур день результаты тюмень тюмгу...
# 1         0  января в рамках го тура чемпионата россии сред...
# 2         0  наставник тюмени тюмгу наталья васильченко о в...
# 3         0  яна чередникова за первую партию нас ругают во...
# 4         0  наталья васильченко девчонки плакали я еле сде...
#
#                                     lines_lemmatized
# 0  [высокий, лига, тур, день, результат, тюмень, ...
# 1  [январь, рамка, го, тур, чемпионат, россия, ср...
# 2  [наставник, тюмень, тюмга, наталья, васильченк...
# 3  [яна, чередникова, первый, партия, ругать, вол...
# 4  [наталья, васильченко, девчонка, плакать, еле,...

# %%
data.shape
# Out:
# (21570, 9)

# %%
data.tail(10)
# Out:
#           id                date   owner_id  \
# 21560   5649 2020-12-30 07:49:22  -45505854
# 21561    149 2020-12-30 06:57:14  623164963
# 21562    982 2020-12-30 06:44:52  324527683
# 21563    980 2020-12-30 06:41:09  -92088231
# 21564  35625 2020-12-30 06:30:03     -29346
# 21565   8938 2020-12-30 06:26:39  -23769646
# 21566    679 2020-12-30 06:23:10 -157348679
# 21567    220 2020-12-30 06:08:00 -192630663
# 21568  18598 2020-12-30 05:26:51 -135160071
# 21569   6076 2020-12-30 05:18:40 -142012747
#
#                                                     text  likes  reposts  \
# 21560  СТУДЕНТКА ИШИМСКОГО ПЕДАГОГИЧЕСКОГО ИНСТИТУТА ...     31       12
# 21561  Особенности обучения иностранных студентов в э...      0        1
# 21562  Позитивный момент в конце отнюдь не балующего ...     22        0
# 21563  #ТПИ #ТобольскийПедагогическийИнститут #Приемн...      7        3
# 21564  [club87603622|Объединенный совет обучающихся Т...     88        7
# 21565  ☃💫Новый год - любимый с детства праздник, самы...      8        1
# 21566  #event@rumts_utmn \n\n✨2020 год стал годом инн...      6        0
# 21567  🍬АССОРТИ ДОСТИЖЕНИЙ: ДЕКАБРЬ 2020🍬 Часть 1.\n ...     10        2
# 21568  Топ-30 разработок сибирских ученых в 2020 году...      1        0
# 21569  Поиск волонтёров!\n \nС 15 января по 11 феврал...      7       14
#
#        comments                                      txt_processed  \
# 21560         0  студентка ишимского педагогического института ...
# 21561         0  особенности обучения иностранных студентов в э...
# 21562         8  позитивный момент в конце отнюдь не балующего ...
# 21563         0  тпи тобольскийпедагогическийинститут приемнаяк...
# 21564         0  объединенный совет обучающихся тюмгу победил в...
# 21565         0  новый год любимый с детства праздник самый кра...
# 21566         0  _ год стал годом инноваций стимулом поиска нов...
# 21567         0  ассорти достижений декабрь часть приближается ...
# 21568         0  топ разработок сибирских ученых в году на порт...
# 21569         0  поиск волонтёров с января по февраля в тюмгу п...
#
#                                         lines_lemmatized
# 21560  [студентка, ишимский, педагогический, институт...
# 21561  [особенность, обучение, иностранный, студент, ...
# 21562  [позитивный, момент, конец, отнюдь, баловать, ...
# 21563  [тпи, тобольскийпедагогическийинститут, приемн...
# 21564  [объединять, совет, обучаться, тюмга, побеждат...
# 21565  [новый, год, любимый, детство, праздник, самый...
# 21566  [_, год, становиться, год, инновация, стимул, ...
# 21567  [ассорти, достижение, декабрь, часть, приближа...
# 21568  [топ, разработка, сибирский, ученый, год, порт...
# 21569  [поиск, волонтер, январь, февраль, тюмга, прой...

# %%
data.to_csv('vk_posts_2019-2020_lemmatized.csv', encoding='utf-8')
